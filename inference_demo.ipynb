# %%
from mmdet.apis import init_detector, inference_detector, show_result_pyplot
import mmcv

# %%
config_file = 'configs/faster_rcnn_x101_64x4d_fpn_TSD_zalo.py'
# download the checkpoint from model zoo and put it in `checkpoints/`
checkpoint_file = 'checkpoints/epoch_3.pth'

# %%
# build the model from a config file and a checkpoint file
model = init_detector(config_file, checkpoint_file, device='cuda:0')

# %%
# test a single image
img = 'data/za_traffic_2020/traffic_public_test/images/23.png'
result = inference_detector(model, img)

# %%
class_names = ["No entry", "No parking / waiting", "No turning", "Max Speed", "Other prohibition signs", "Warning", "Mandatory"]

# %%
# show the results
show_result_pyplot(img, result, class_names)
